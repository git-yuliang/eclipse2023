# %% [markdown]
# # **Sun-as-a-star analysis of coronal high-frequency quasi-periodic oscillations observed by an iPhone during the total solar eclipse of 20 April 2023 with 240 fps imaging**
# ### **Data Processing and Analysis Notebook**
#
# **Authors**: [Yu Liang]
# **Affiliation**: [Shanghai Astronomical Observatory, Chinese Academy of Sciences, Shanghai 200030, China]
# **Contact**: [yuliang@shao.ac.cn]
# **Last Updated**: [2024-12-10]
#
# ---
#
# ### **Notebook Overview**
#
# These Jupyter Notebook documents the processing and analysis of observational data collected during the 2023 total solar eclipse. The primary objectives of this Notebook include:
#
# 1. Preprocessing of raw white-light corona imaging data (dark field subtraction, flat field correction, and temporal registration).
# 2. Application of wavelet analysis to detect high-frequency quasi-periodic oscillations (HFQPOs).
# 3. Visualizations of the solar corona and statistical results for Sun-as-a-star analysis.
#
# ---
#
# ### **Dependencies**
#
# The analysis relies on the following Python libraries (compatible versions):
# - `numpy==1.2.43`
# - `pandas==1.5.1`
# - `scikit-image==0.20.0`
# - `matplotlib==3.7.1`
# - `astropy==5.1.1`
# - `opencv-python==4.7.0.72`
#
# <!-- A complete list of dependencies can be found in the accompanying `requirements.txt`. -->
#
# ---
#
# ### **Data Source**
#
# - **Observation Site**: Learmonth Airport, Australia
# - **Instrument**: iPhone with 565 nm filter, sampling at 240 fps, frams width * height: 720.0 * 1280.0, image shape:(1280, 720, 3)
# - **Date**: April 20, 2023
#
# ---
#
# ### **Main Structure**
#
# - **Section 1**: Data loading and inspection
# - **Section 2**: Preprocessing (dark field, flat field, and registration)
# - **Section 3**: Wavelet analysis and signal detection
# - **Section 4**: Results visualization and discussion

# %% [markdown]
# ---
# ### **Notebook 1.0**
# #### The extraction of individual frames from the observed video, stored in .mov format, using the `VideoCapture` function from the OpenCV library.
# - input: *.mov, *.mp4
# - output: *.jpg
#
# STEP 1: load data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
import numpy as np
from astropy.io import fits
import skimage.io as io
import cv2
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
path0 = '/Volumes/WD1T/share/TSE2023/'                                      # Parent folder
pathmc = '/Volumes/WD1T/share/TSE2023/iPhone/cut/'                          # input dir of the cut moive of the original data, to aviod the 

dir1  = path0 + 'iPhone/result/m2pic/'                                      # output dir for saving the frames extracted by the moive
if not os.path.exists(dir1):
    os.makedirs(dir1)

# %%
list0 = os.listdir(pathmc)
list0.sort()
print(list0)
print(len(list0))
# Out:
# ['._My Movie.mp4', '._dark.MOV', '._flat.mov', '._totally.mp4', 'My Movie.mp4', 'dark.MOV', 'flat.mov', 'totally.mp4']
# 8

# %%
# cv2.VideoCapture.get(0)  Current position of the video file (playback) in milliseconds.
# cv2.VideoCapture.get(1)  Index of the current frame, based on a zero-based index of captured or decoded frames.
# cv2.VideoCapture.get(2)  Relative position of the video file (playback): 0 = start of the movie, 1 = end of the movie.
# cv2.VideoCapture.get(3)  Width of the frames in the video stream.
# cv2.VideoCapture.get(4)  Height of the frames in the video stream.
# cv2.VideoCapture.get(5)  Frame rate.
# cv2.VideoCapture.get(6)  4-character code of the codec.
# cv2.VideoCapture.get(7)  Number of frames in the video file.

# %%
vidcap = cv2.VideoCapture(pathmc + 'flat.mov')
success, image = vidcap.read()
print(success)
print(image.shape)
print('frams width, height:',vidcap.get(3), vidcap.get(4))
print('frams rate:',vidcap.get(cv2.CAP_PROP_FPS))
print('total frams:',vidcap.get(7))
print('frame now:',vidcap.get(1))
# Out:
# True
# (720, 1280, 3)
# frams width, height: 1280.0 720.0
# frams rate: 29.892086330935253
# total frams: 554.0
# frame now: 1.0

# %%
vidcap = cv2.VideoCapture(pathmc + 'totally.mp4')
success, image = vidcap.read()
print(success)
print(image.shape)
print('frams width, height:',vidcap.get(3), vidcap.get(4))
print('frams rate:',vidcap.get(cv2.CAP_PROP_FPS))
print('total frams:',vidcap.get(7))
print('frame now:',vidcap.get(1))
# Out:
# True
# (720, 1280, 3)
# frams width, height: 1280.0 720.0
# frams rate: 29.97002997002997
# total frams: 13283.0
# frame now: 1.0

# %% [markdown]
# ---
# ### **Notebook 1.0**
# #### The extraction of individual frames from the observed video, stored in .mov format, using the `VideoCapture` function from the OpenCV library.
#
# STEP 2: extraction the individual frames from the observed video

# %%
vidcap = cv2.VideoCapture(pathmc + list0[7])
success, image = vidcap.read()

count = 0
while success:
  
  cv2.imwrite(dir1 +'image_%d.jpg' % count, image)    
  success, image = vidcap.read()
  print('Saved image ', count, '----------frame now:',vidcap.get(1))
  count += 1
# Out:
# Saved image  0 ----------frame now: 2.0
# Saved image  1 ----------frame now: 3.0
# Saved image  2 ----------frame now: 4.0
# Saved image  3 ----------frame now: 5.0
# Saved image  4 ----------frame now: 6.0
# Saved image  5 ----------frame now: 7.0
# Saved image  6 ----------frame now: 8.0
# Saved image  7 ----------frame now: 9.0
# Saved image  8 ----------frame now: 10.0
# Saved image  9 ----------frame now: 11.0
# Saved image  10 ----------frame now: 12.0
# Saved image  11 ----------frame now: 13.0
# Saved image  12 ----------frame now: 14.0
# Saved image  13 ----------frame now: 15.0
# Saved image  14 ----------frame now: 16.0
# Saved image  15 ----------frame now: 17.0
# Saved image  16 ----------frame now: 18.0
# Saved image  17 ----------frame now: 19.0
# Saved image  18 ----------frame now: 20.0
# Saved image  19 ----------frame now: 21.0
# Saved image  20 ----------frame now: 22.0
# Saved image  21 ----------frame now: 23.0
# Saved image  22 ----------frame now: 24.0
# Saved image  23 ----------frame now: 25.0
# Saved image  24 ----------frame now: 26.0
# Saved image  25 ----------frame now: 27.0
# Saved image  26 ----------frame now: 28.0
# Saved image  27 ----------frame now: 29.0
# Saved image  28 ----------frame now: 30.0
# Saved image  29 ----------frame now: 31.0
# Saved image  30 ----------frame now: 32.0
# Saved image  31 ----------frame now: 33.0
# Saved image  32 ----------frame now: 34.0
# Saved image  33 ----------frame now: 35.0
# Saved image  34 ----------frame now: 36.0
# Saved image  35 ----------frame now: 37.0
# Saved image  36 ----------frame now: 38.0
# Saved image  37 ----------frame now: 39.0
# Saved image  38 ----------frame now: 40.0
# Saved image  39 ----------frame now: 41.0
# Saved image  40 ----------frame now: 42.0
# Saved image  41 ----------frame now: 43.0
# Saved image  42 ----------frame now: 44.0
# Saved image  43 ----------frame now: 45.0
# Saved image  44 ----------frame now: 46.0
# Saved image  45 ----------frame now: 47.0
# Saved image  46 ----------frame now: 48.0
# Saved image  47 ----------frame now: 49.0
# Saved image  48 ----------frame now: 50.0
# Saved image  49 ----------frame now: 51.0
# Saved image  50 ----------frame now: 52.0
# Saved image  51 ----------frame now: 53.0
# Saved image  52 ----------frame now: 54.0
# Saved image  53 ----------frame now: 55.0
# Saved image  54 ----------frame now: 56.0
# Saved image  55 ----------frame now: 57.0
# Saved image  56 ----------frame now: 58.0
# Saved image  57 ----------frame now: 59.0
# Saved image  58 ----------frame now: 60.0
# Saved image  59 ----------frame now: 61.0
# Saved image  60 ----------frame now: 62.0
# Saved image  61 ----------frame now: 63.0
# Saved image  62 ----------frame now: 64.0
# Saved image  63 ----------frame now: 65.0
# Saved image  64 ----------frame now: 66.0
# Saved image  65 ----------frame now: 67.0
# Saved image  66 ----------frame now: 68.0
# Saved image  67 ----------frame now: 69.0
# Saved image  68 ----------frame now: 70.0
# Saved image  69 ----------frame now: 71.0
# Saved image  70 ----------frame now: 72.0
# Saved image  71 ----------frame now: 73.0
# Saved image  72 ----------frame now: 74.0
# Saved image  73 ----------frame now: 75.0
# Saved image  74 ----------frame now: 76.0
# Saved image  75 ----------frame now: 77.0
# Saved image  76 ----------frame now: 78.0
# Saved image  77 ----------frame now: 79.0
# Saved image  78 ----------frame now: 80.0
# Saved image  79 ----------frame now: 81.0
# Saved image  80 ----------frame now: 82.0
# Saved image  81 ----------frame now: 83.0
# Saved image  82 ----------frame now: 84.0
# Saved image  83 ----------frame now: 85.0
# Saved image  84 ----------frame now: 86.0
# Saved image  85 ----------frame now: 87.0
# Saved image  86 ----------frame now: 88.0
# Saved image  87 ----------frame now: 89.0
# Saved image  88 ----------frame now: 90.0
# Saved image  89 ----------frame now: 91.0
# Saved image  90 ----------frame now: 92.0
# Saved image  91 ----------frame now: 93.0
# Saved image  92 ----------frame now: 94.0
# Saved image  93 ----------frame now: 95.0
# Saved image  94 ----------frame now: 96.0
# Saved image  95 ----------frame now: 97.0
# Saved image  96 ----------frame now: 98.0
# Saved image  97 ----------frame now: 99.0
# Saved image  98 ----------frame now: 100.0
# Saved image  99 ----------frame now: 101.0
# Saved image  100 ----------frame now: 102.0
# Saved image  101 ----------frame now: 103.0
# Saved image  102 ----------frame now: 104.0
# Saved image  103 ----------frame now: 105.0
# Saved image  104 ----------frame now: 106.0
# Saved image  105 ----------frame now: 107.0
# Saved image  106 ----------frame now: 108.0
# Saved image  107 ----------frame now: 109.0
# Saved image  108 ----------frame now: 110.0
# Saved image  109 ----------frame now: 111.0
# Saved image  110 ----------frame now: 112.0
# Saved image  111 ----------frame now: 113.0
# Saved image  112 ----------frame now: 114.0
# Saved image  113 ----------frame now: 115.0
# Saved image  114 ----------frame now: 116.0
# Saved image  115 ----------frame now: 117.0
# Saved image  116 ----------frame now: 118.0
# Saved image  117 ----------frame now: 119.0
# Saved image  118 ----------frame now: 120.0
# Saved image  119 ----------frame now: 121.0
# Saved image  120 ----------frame now: 122.0
# Saved image  121 ----------frame now: 123.0
# Saved image  122 ----------frame now: 124.0
# Saved image  123 ----------frame now: 125.0
# Saved image  124 ----------frame now: 126.0
# Saved image  125 ----------frame now: 127.0
# Saved image  126 ----------frame now: 128.0
# Saved image  127 ----------frame now: 129.0
# Saved image  128 ----------frame now: 130.0
# Saved image  129 ----------frame now: 131.0
# Saved image  130 ----------frame now: 132.0
# Saved image  131 ----------frame now: 133.0
# Saved image  132 ----------frame now: 134.0
# Saved image  133 ----------frame now: 135.0
# Saved image  134 ----------frame now: 136.0
# Saved image  135 ----------frame now: 137.0
# Saved image  136 ----------frame now: 138.0
# Saved image  137 ----------frame now: 139.0
# Saved image  138 ----------frame now: 140.0
# Saved image  139 ----------frame now: 141.0
# Saved image  140 ----------frame now: 142.0
# Saved image  141 ----------frame now: 143.0
# Saved image  142 ----------frame now: 144.0
# Saved image  143 ----------frame now: 145.0
# Saved image  144 ----------frame now: 146.0
# Saved image  145 ----------frame now: 147.0
# Saved image  146 ----------frame now: 148.0
# Saved image  147 ----------frame now: 149.0
# Saved image  148 ----------frame now: 150.0
# Saved image  149 ----------frame now: 151.0
# Saved image  150 ----------frame now: 152.0
# Saved image  151 ----------frame now: 153.0
# Saved image  152 ----------frame now: 154.0
# Saved image  153 ----------frame now: 155.0
# Saved image  154 ----------frame now: 156.0
# Saved image  155 ----------frame now: 157.0
# Saved image  156 ----------frame now: 158.0
# Saved image  157 ----------frame now: 159.0
# Saved image  158 ----------frame now: 160.0
# Saved image  159 ----------frame now: 161.0
# Saved image  160 ----------frame now: 162.0
# Saved image  161 ----------frame now: 163.0
# Saved image  162 ----------frame now: 164.0
# Saved image  163 ----------frame now: 165.0
# Saved image  164 ----------frame now: 166.0
# Saved image  165 ----------frame now: 167.0
# Saved image  166 ----------frame now: 168.0
# Saved image  167 ----------frame now: 169.0
# Saved image  168 ----------frame now: 170.0
# Saved image  169 ----------frame now: 171.0
# Saved image  170 ----------frame now: 172.0
# Saved image  171 ----------frame now: 173.0
# Saved image  172 ----------frame now: 174.0
# Saved image  173 ----------frame now: 175.0
# Saved image  174 ----------frame now: 176.0
# Saved image  175 ----------frame now: 177.0
# Saved image  176 ----------frame now: 178.0
# Saved image  177 ----------frame now: 179.0
# Saved image  178 ----------frame now: 180.0
# Saved image  179 ----------frame now: 181.0
# Saved image  180 ----------frame now: 182.0
# Saved image  181 ----------frame now: 183.0
# Saved image  182 ----------frame now: 184.0
# Saved image  183 ----------frame now: 185.0
# Saved image  184 ----------frame now: 186.0
# Saved image  185 ----------frame now: 187.0
# Saved image  186 ----------frame now: 188.0
# Saved image  187 ----------frame now: 189.0
# Saved image  188 ----------frame now: 190.0
# Saved image  189 ----------frame now: 191.0
# Saved image  190 ----------frame now: 192.0
# Saved image  191 ----------frame now: 193.0
# Saved image  192 ----------frame now: 194.0
# Saved image  193 ----------frame now: 195.0
# Saved image  194 ----------frame now: 196.0
# Saved image  195 ----------frame now: 197.0
# Saved image  196 ----------frame now: 198.0
# Saved image  197 ----------frame now: 199.0
# Saved image  198 ----------frame now: 200.0
# Saved image  199 ----------frame now: 201.0
# Saved image  200 ----------frame now: 202.0
# Saved image  201 ----------frame now: 203.0
# Saved image  202 ----------frame now: 204.0
# Saved image  203 ----------frame now: 205.0
# Saved image  204 ----------frame now: 206.0
# Saved image  205 ----------frame now: 207.0
# Saved image  206 ----------frame now: 208.0
# Saved image  207 ----------frame now: 209.0
# Saved image  208 ----------frame now: 210.0
# Saved image  209 ----------frame now: 211.0
# Saved image  210 ----------frame now: 212.0
# Saved image  211 ----------frame now: 213.0
# Saved image  212 ----------frame now: 214.0
# Saved image  213 ----------frame now: 215.0
# Saved image  214 ----------frame now: 216.0
# Saved image  215 ----------frame now: 217.0
# Saved image  216 ----------frame now: 218.0
# Saved image  217 ----------frame now: 219.0
# Saved image  218 ----------frame now: 220.0
# Saved image  219 ----------frame now: 221.0
# Saved image  220 ----------frame now: 222.0
# Saved image  221 ----------frame now: 223.0
# Saved image  222 ----------frame now: 224.0
# Saved image  223 ----------frame now: 225.0
# Saved image  224 ----------frame now: 226.0
# Saved image  225 ----------frame now: 227.0
# Saved image  226 ----------frame now: 228.0
# Saved image  227 ----------frame now: 229.0
# Saved image  228 ----------frame now: 230.0
# Saved image  229 ----------frame now: 231.0
# Saved image  230 ----------frame now: 232.0
# Saved image  231 ----------frame now: 233.0
# Saved image  232 ----------frame now: 234.0
# Saved image  233 ----------frame now: 235.0
# Saved image  234 ----------frame now: 236.0
# Saved image  235 ----------frame now: 237.0
# Saved image  236 ----------frame now: 238.0
# Saved image  237 ----------frame now: 239.0
# Saved image  238 ----------frame now: 240.0
# Saved image  239 ----------frame now: 241.0
# Saved image  240 ----------frame now: 242.0
# Saved image  241 ----------frame now: 243.0
# Saved image  242 ----------frame now: 244.0
# Saved image  243 ----------frame now: 245.0
# Saved image  244 ----------frame now: 246.0
# Saved image  245 ----------frame now: 247.0
# Saved image  246 ----------frame now: 248.0
# Saved image  247 ----------frame now: 249.0
# Saved image  248 ----------frame now: 250.0
# Saved image  249 ----------frame now: 251.0
# Saved image  250 ----------frame now: 252.0
# Saved image  251 ----------frame now: 253.0
# Saved image  252 ----------frame now: 254.0
# Saved image  253 ----------frame now: 255.0
# Saved image  254 ----------frame now: 256.0
# Saved image  255 ----------frame now: 257.0
# Saved image  256 ----------frame now: 258.0
# Saved image  257 ----------frame now: 259.0
# Saved image  258 ----------frame now: 260.0
# Saved image  259 ----------frame now: 261.0
# Saved image  260 ----------frame now: 262.0
# Saved image  261 ----------frame now: 263.0
# Saved image  262 ----------frame now: 264.0
# Saved image  263 ----------frame now: 265.0
# Saved image  264 ----------frame now: 266.0
# Saved image  265 ----------frame now: 267.0
# Saved image  266 ----------frame now: 268.0
# Saved image  267 ----------frame now: 269.0
# Saved image  268 ----------frame now: 270.0
# Saved image  269 ----------frame now: 271.0
# Saved image  270 ----------frame now: 272.0
# Saved image  271 ----------frame now: 273.0
# Saved image  272 ----------frame now: 274.0
# Saved image  273 ----------frame now: 275.0
# Saved image  274 ----------frame now: 276.0
# Saved image  275 ----------frame now: 277.0
# Saved image  276 ----------frame now: 278.0
# Saved image  277 ----------frame now: 279.0
# Saved image  278 ----------frame now: 280.0
# Saved image  279 ----------frame now: 281.0
# Saved image  280 ----------frame now: 282.0
# Saved image  281 ----------frame now: 283.0
# Saved image  282 ----------frame now: 284.0
# Saved image  283 ----------frame now: 285.0
# Saved image  284 ----------frame now: 286.0
# Saved image  285 ----------frame now: 287.0
# Saved image  286 ----------frame now: 288.0
# Saved image  287 ----------frame now: 289.0
# Saved image  288 ----------frame now: 290.0
# Saved image  289 ----------frame now: 291.0
# Saved image  290 ----------frame now: 292.0
# Saved image  291 ----------frame now: 293.0
# Saved image  292 ----------frame now: 294.0
# Saved image  293 ----------frame now: 295.0
# Saved image  294 ----------frame now: 296.0
# Saved image  295 ----------frame now: 297.0
# Saved image  296 ----------frame now: 298.0
# Saved image  297 ----------frame now: 299.0
# Saved image  298 ----------frame now: 300.0
# Saved image  299 ----------frame now: 301.0
# Saved image  300 ----------frame now: 302.0
# Saved image  301 ----------frame now: 303.0
# Saved image  302 ----------frame now: 304.0
# Saved image  303 ----------frame now: 305.0
# Saved image  304 ----------frame now: 306.0
# Saved image  305 ----------frame now: 307.0
# Saved image  306 ----------frame now: 308.0
# Saved image  307 ----------frame now: 309.0
# Saved image  308 ----------frame now: 310.0
# Saved image  309 ----------frame now: 311.0
# Saved image  310 ----------frame now: 312.0
# Saved image  311 ----------frame now: 313.0
# Saved image  312 ----------frame now: 314.0
# Saved image  313 ----------frame now: 315.0
# Saved image  314 ----------frame now: 316.0
# Saved image  315 ----------frame now: 317.0
# Saved image  316 ----------frame now: 318.0
# Saved image  317 ----------frame now: 319.0
# Saved image  318 ----------frame now: 320.0
# Saved image  319 ----------frame now: 321.0
# Saved image  320 ----------frame now: 322.0
# Saved image  321 ----------frame now: 323.0
# Saved image  322 ----------frame now: 324.0
# Saved image  323 ----------frame now: 325.0
# Saved image  324 ----------frame now: 326.0
# Saved image  325 ----------frame now: 327.0
# Saved image  326 ----------frame now: 328.0
# Saved image  327 ----------frame now: 329.0
# Saved image  328 ----------frame now: 330.0
# Saved image  329 ----------frame now: 331.0
# Saved image  330 ----------frame now: 332.0
# Saved image  331 ----------frame now: 333.0
# Saved image  332 ----------frame now: 334.0
# Saved image  333 ----------frame now: 335.0
# Saved image  334 ----------frame now: 336.0
# Saved image  335 ----------frame now: 337.0
# Saved image  336 ----------frame now: 338.0
# Saved image  337 ----------frame now: 339.0
# Saved image  338 ----------frame now: 340.0
# Saved image  339 ----------frame now: 341.0
# Saved image  340 ----------frame now: 342.0
# Saved image  341 ----------frame now: 343.0
# Saved image  342 ----------frame now: 344.0
# Saved image  343 ----------frame now: 345.0
# Saved image  344 ----------frame now: 346.0
# Saved image  345 ----------frame now: 347.0
# Saved image  346 ----------frame now: 348.0
# Saved image  347 ----------frame now: 349.0
# Saved image  348 ----------frame now: 350.0
# Saved image  349 ----------frame now: 351.0
# Saved image  350 ----------frame now: 352.0
# Saved image  351 ----------frame now: 353.0
# Saved image  352 ----------frame now: 354.0
# Saved image  353 ----------frame now: 355.0
# Saved image  354 ----------frame now: 356.0
# Saved image  355 ----------frame now: 357.0
# Saved image  356 ----------frame now: 358.0
# Saved image  357 ----------frame now: 359.0
# Saved image  358 ----------frame now: 360.0
# Saved image  359 ----------frame now: 361.0
# Saved image  360 ----------frame now: 362.0
# Saved image  361 ----------frame now: 363.0
# Saved image  362 ----------frame now: 364.0
# Saved image  363 ----------frame now: 365.0
# Saved image  364 ----------frame now: 366.0
# Saved image  365 ----------frame now: 367.0
# Saved image  366 ----------frame now: 368.0
# Saved image  367 ----------frame now: 369.0
# Saved image  368 ----------frame now: 370.0
# Saved image  369 ----------frame now: 371.0
# Saved image  370 ----------frame now: 372.0
# Saved image  371 ----------frame now: 373.0
# Saved image  372 ----------frame now: 374.0
# Saved image  373 ----------frame now: 375.0
# Saved image  374 ----------frame now: 376.0
# Saved image  375 ----------frame now: 377.0
# Saved image  376 ----------frame now: 378.0
# Saved image  377 ----------frame now: 379.0
# Saved image  378 ----------frame now: 380.0
# Saved image  379 ----------frame now: 381.0
# Saved image  380 ----------frame now: 382.0
# Saved image  381 ----------frame now: 383.0
# Saved image  382 ----------frame now: 384.0
# Saved image  383 ----------frame now: 385.0
# Saved image  384 ----------frame now: 386.0
# Saved image  385 ----------frame now: 387.0
# Saved image  386 ----------frame now: 388.0
# Saved image  387 ----------frame now: 389.0
# Saved image  388 ----------frame now: 390.0
# Saved image  389 ----------frame now: 391.0
# Saved image  390 ----------frame now: 392.0
# Saved image  391 ----------frame now: 393.0
# Saved image  392 ----------frame now: 394.0
# Saved image  393 ----------frame now: 395.0
# Saved image  394 ----------frame now: 396.0
# Saved image  395 ----------frame now: 397.0
# Saved image  396 ----------frame now: 398.0
# Saved image  397 ----------frame now: 399.0
# Saved image  398 ----------frame now: 400.0
# Saved image  399 ----------frame now: 401.0
# Saved image  400 ----------frame now: 402.0
# Saved image  401 ----------frame now: 403.0
# Saved image  402 ----------frame now: 404.0
# Saved image  403 ----------frame now: 405.0
# Saved image  404 ----------frame now: 406.0
# Saved image  405 ----------frame now: 407.0
# Saved image  406 ----------frame now: 408.0
# Saved image  407 ----------frame now: 409.0
# Saved image  408 ----------frame now: 410.0
# Saved image  409 ----------frame now: 411.0
# Saved image  410 ----------frame now: 412.0
# Saved image  411 ----------frame now: 413.0
# Saved image  412 ----------frame now: 414.0
# Saved image  413 ----------frame now: 415.0
# Saved image  414 ----------frame now: 416.0
# Saved image  415 ----------frame now: 417.0
# Saved image  416 ----------frame now: 418.0
# Saved image  417 ----------frame now: 419.0
# Saved image  418 ----------frame now: 420.0
# Saved image  419 ----------frame now: 421.0
# Saved image  420 ----------frame now: 422.0
# Saved image  421 ----------frame now: 423.0
# Saved image  422 ----------frame now: 424.0
# Saved image  423 ----------frame now: 425.0
# Saved image  424 ----------frame now: 426.0
# Saved image  425 ----------frame now: 427.0
# Saved image  426 ----------frame now: 428.0
# Saved image  427 ----------frame now: 429.0
# Saved image  428 ----------frame now: 430.0
# Saved image  429 ----------frame now: 431.0
# Saved image  430 ----------frame now: 432.0
# Saved image  431 ----------frame now: 433.0
# Saved image  432 ----------frame now: 434.0
# Saved image  433 ----------frame now: 435.0
# Saved image  434 ----------frame now: 436.0
# Saved image  435 ----------frame now: 437.0
# Saved image  436 ----------frame now: 438.0
# Saved image  437 ----------frame now: 439.0
# Saved image  438 ----------frame now: 440.0
# Saved image  439 ----------frame now: 441.0
# Saved image  440 ----------frame now: 442.0
# Saved image  441 ----------frame now: 443.0
# Saved image  442 ----------frame now: 444.0
# Saved image  443 ----------frame now: 445.0
# Saved image  444 ----------frame now: 446.0
# Saved image  445 ----------frame now: 447.0
# Saved image  446 ----------frame now: 448.0
# Saved image  447 ----------frame now: 449.0
# Saved image  448 ----------frame now: 450.0
# Saved image  449 ----------frame now: 451.0
# Saved image  450 ----------frame now: 452.0
# Saved image  451 ----------frame now: 453.0
# Saved image  452 ----------frame now: 454.0
# Saved image  453 ----------frame now: 455.0
# Saved image  454 ----------frame now: 456.0
# Saved image  455 ----------frame now: 457.0
# Saved image  456 ----------frame now: 458.0
# Saved image  457 ----------frame now: 459.0
# Saved image  458 ----------frame now: 460.0
# Saved image  459 ----------frame now: 461.0
# Saved image  460 ----------frame now: 462.0
# Saved image  461 ----------frame now: 463.0
# Saved image  462 ----------frame now: 464.0
# Saved image  463 ----------frame now: 465.0
# Saved image  464 ----------frame now: 466.0
# Saved image  465 ----------frame now: 467.0
# Saved image  466 ----------frame now: 468.0
# Saved image  467 ----------frame now: 469.0
# Saved image  468 ----------frame now: 470.0
# Saved image  469 ----------frame now: 471.0
# Saved image  470 ----------frame now: 472.0
# Saved image  471 ----------frame now: 473.0
# Saved image  472 ----------frame now: 474.0
# Saved image  473 ----------frame now: 475.0
# Saved image  474 ----------frame now: 476.0
# Saved image  475 ----------frame now: 477.0
# Saved image  476 ----------frame now: 478.0
# Saved image  477 ----------frame now: 479.0
# Saved image  478 ----------frame now: 480.0
# Saved image  479 ----------frame now: 481.0
# Saved image  480 ----------frame now: 482.0
# Saved image  481 ----------frame now: 483.0
# Saved image  482 ----------frame now: 484.0
# Saved image  483 ----------frame now: 485.0
# Saved image  484 ----------frame now: 486.0
# Saved image  485 ----------frame now: 487.0
# Saved image  486 ----------frame now: 488.0
# Saved image  487 ----------frame now: 489.0
# Saved image  488 ----------frame now: 490.0
# Saved image  489 ----------frame now: 491.0
# Saved image  490 ----------frame now: 492.0
# Saved image  491 ----------frame now: 493.0
# Saved image  492 ----------frame now: 494.0
# Saved image  493 ----------frame now: 495.0
# Saved image  494 ----------frame now: 496.0
# Saved image  495 ----------frame now: 497.0
# Saved image  496 ----------frame now: 498.0
# Saved image  497 ----------frame now: 499.0
# Saved image  498 ----------frame now: 500.0
# Saved image  499 ----------frame now: 501.0
# Saved image  500 ----------frame now: 502.0
# Saved image  501 ----------frame now: 503.0
# Saved image  502 ----------frame now: 504.0
# Saved image  503 ----------frame now: 505.0
# Saved image  504 ----------frame now: 506.0
# Saved image  505 ----------frame now: 507.0
# Saved image  506 ----------frame now: 508.0
# Saved image  507 ----------frame now: 509.0
# Saved image  508 ----------frame now: 510.0
# Saved image  509 ----------frame now: 511.0
# Saved image  510 ----------frame now: 512.0
# Saved image  511 ----------frame now: 513.0
# Saved image  512 ----------frame now: 514.0
# Saved image  513 ----------frame now: 515.0
# Saved image  514 ----------frame now: 516.0
# Saved image  515 ----------frame now: 517.0
# Saved image  516 ----------frame now: 518.0
# Saved image  517 ----------frame now: 519.0
# Saved image  518 ----------frame now: 520.0
# Saved image  519 ----------frame now: 521.0
# Saved image  520 ----------frame now: 522.0
# Saved image  521 ----------frame now: 523.0
# Saved image  522 ----------frame now: 524.0
# Saved image  523 ----------frame now: 525.0
# Saved image  524 ----------frame now: 526.0
# Saved image  525 ----------frame now: 527.0
# Saved image  526 ----------frame now: 528.0
# Saved image  527 ----------frame now: 529.0
# Saved image  528 ----------frame now: 530.0
# Saved image  529 ----------frame now: 531.0
# Saved image  530 ----------frame now: 532.0
# Saved image  531 ----------frame now: 533.0
# Saved image  532 ----------frame now: 534.0
# Saved image  533 ----------frame now: 535.0
# Saved image  534 ----------frame now: 536.0
# Saved image  535 ----------frame now: 537.0
# Saved image  536 ----------frame now: 538.0
# Saved image  537 ----------frame now: 539.0
# Saved image  538 ----------frame now: 540.0
# Saved image  539 ----------frame now: 541.0
# Saved image  540 ----------frame now: 542.0
# Saved image  541 ----------frame now: 543.0
# Saved image  542 ----------frame now: 544.0
# Saved image  543 ----------frame now: 545.0
# Saved image  544 ----------frame now: 546.0
# Saved image  545 ----------frame now: 547.0
# Saved image  546 ----------frame now: 548.0
# Saved image  547 ----------frame now: 549.0
# Saved image  548 ----------frame now: 550.0
# Saved image  549 ----------frame now: 551.0
# Saved image  550 ----------frame now: 552.0
# Saved image  551 ----------frame now: 553.0
# Saved image  552 ----------frame now: 554.0
# Saved image  553 ----------frame now: 555.0
# Saved image  554 ----------frame now: 556.0
# Saved image  555 ----------frame now: 557.0
# Saved image  556 ----------frame now: 558.0
# Saved image  557 ----------frame now: 559.0
# Saved image  558 ----------frame now: 560.0
# Saved image  559 ----------frame now: 561.0
# Saved image  560 ----------frame now: 562.0
# Saved image  561 ----------frame now: 563.0
# Saved image  562 ----------frame now: 564.0
# Saved image  563 ----------frame now: 565.0
# Saved image  564 ----------frame now: 566.0
# Saved image  565 ----------frame now: 567.0
# Saved image  566 ----------frame now: 568.0
# Saved image  567 ----------frame now: 569.0
# Saved image  568 ----------frame now: 570.0
# Saved image  569 ----------frame now: 571.0
# Saved image  570 ----------frame now: 572.0
# Saved image  571 ----------frame now: 573.0
# Saved image  572 ----------frame now: 574.0
# Saved image  573 ----------frame now: 575.0
# Saved image  574 ----------frame now: 576.0
# Saved image  575 ----------frame now: 577.0
# Saved image  576 ----------frame now: 578.0
# Saved image  577 ----------frame now: 579.0
# Saved image  578 ----------frame now: 580.0
# Saved image  579 ----------frame now: 581.0
# Saved image  580 ----------frame now: 582.0
# Saved image  581 ----------frame now: 583.0
# Saved image  582 ----------frame now: 584.0
# Saved image  583 ----------frame now: 585.0
# Saved image  584 ----------frame now: 586.0
# Saved image  585 ----------frame now: 587.0
# Saved image  586 ----------frame now: 588.0
# Saved image  587 ----------frame now: 589.0
# Saved image  588 ----------frame now: 590.0
# Saved image  589 ----------frame now: 591.0
# Saved image  590 ----------frame now: 592.0
# Saved image  591 ----------frame now: 593.0
# Saved image  592 ----------frame now: 594.0
# Saved image  593 ----------frame now: 595.0
# Saved image  594 ----------frame now: 596.0
# Saved image  595 ----------frame now: 597.0
# Saved image  596 ----------frame now: 598.0
# Saved image  597 ----------frame now: 599.0
# Saved image  598 ----------frame now: 600.0
# Saved image  599 ----------frame now: 601.0
# Saved image  600 ----------frame now: 602.0
# Saved image  601 ----------frame now: 603.0
# Saved image  602 ----------frame now: 604.0
# Saved image  603 ----------frame now: 605.0
# Saved image  604 ----------frame now: 606.0
# Saved image  605 ----------frame now: 607.0
# Saved image  606 ----------frame now: 608.0
# Saved image  607 ----------frame now: 609.0
# Saved image  608 ----------frame now: 610.0
# Saved image  609 ----------frame now: 611.0
# Saved image  610 ----------frame now: 612.0
# Saved image  611 ----------frame now: 613.0
# Saved image  612 ----------frame now: 614.0
# Saved image  613 ----------frame now: 615.0
# Saved image  614 ----------frame now: 616.0
# Saved image  615 ----------frame now: 617.0
# Saved image  616 ----------frame now: 618.0
# Saved image  617 ----------frame now: 619.0
# Saved image  618 ----------frame now: 620.0
# Saved image  619 ----------frame now: 621.0
# Saved image  620 ----------frame now: 622.0
# Saved image  621 ----------frame now: 623.0
# Saved image  622 ----------frame now: 624.0
# Saved image  623 ----------frame now: 625.0
# Saved image  624 ----------frame now: 626.0
# Saved image  625 ----------frame now: 627.0
# Saved image  626 ----------frame now: 628.0
# Saved image  627 ----------frame now: 629.0
# Saved image  628 ----------frame now: 630.0
# Saved image  629 ----------frame now: 631.0
# Saved image  630 ----------frame now: 632.0
# Saved image  631 ----------frame now: 633.0
# Saved image  632 ----------frame now: 634.0
# Saved image  633 ----------frame now: 635.0
# Saved image  634 ----------frame now: 636.0
# Saved image  635 ----------frame now: 637.0
# Saved image  636 ----------frame now: 638.0
# Saved image  637 ----------frame now: 639.0
# Saved image  638 ----------frame now: 640.0
# Saved image  639 ----------frame now: 641.0
# Saved image  640 ----------frame now: 642.0
# Saved image  641 ----------frame now: 643.0
# Saved image  642 ----------frame now: 644.0
# Saved image  643 ----------frame now: 645.0
# Saved image  644 ----------frame now: 646.0
# Saved image  645 ----------frame now: 647.0
# Saved image  646 ----------frame now: 648.0
# Saved image  647 ----------frame now: 649.0
# Saved image  648 ----------frame now: 650.0
# Saved image  649 ----------frame now: 651.0
# Saved image  650 ----------frame now: 652.0
# Saved image  651 ----------frame now: 653.0
# Saved image  652 ----------frame now: 654.0
# Saved image  653 ----------frame now: 655.0
# Saved image  654 ----------frame now: 656.0
# Saved image  655 ----------frame now: 657.0
# Saved image  656 ----------frame now: 658.0
# Saved image  657 ----------frame now: 659.0
# Saved image  658 ----------frame now: 660.0
# Saved image  659 ----------frame now: 661.0
# Saved image  660 ----------frame now: 662.0
# Saved image  661 ----------frame now: 663.0
# Saved image  662 ----------frame now: 664.0
# Saved image  663 ----------frame now: 665.0
# Saved image  664 ----------frame now: 666.0
# Saved image  665 ----------frame now: 667.0
# Saved image  666 ----------frame now: 668.0
# Saved image  667 ----------frame now: 669.0
# Saved image  668 ----------frame now: 670.0
# Saved image  669 ----------frame now: 671.0
# Saved image  670 ----------frame now: 672.0
# Saved image  671 ----------frame now: 673.0
# Saved image  672 ----------frame now: 674.0
# Saved image  673 ----------frame now: 675.0
# Saved image  674 ----------frame now: 676.0
# Saved image  675 ----------frame now: 677.0
# Saved image  676 ----------frame now: 678.0
# Saved image  677 ----------frame now: 679.0
# Saved image  678 ----------frame now: 680.0
# Saved image  679 ----------frame now: 681.0
# Saved image  680 ----------frame now: 682.0
# Saved image  681 ----------frame now: 683.0
# Saved image  682 ----------frame now: 684.0
# Saved image  683 ----------frame now: 685.0
# Saved image  684 ----------frame now: 686.0
# Saved image  685 ----------frame now: 687.0
# Saved image  686 ----------frame now: 688.0
# Saved image  687 ----------frame now: 689.0
# Saved image  688 ----------frame now: 690.0
# Saved image  689 ----------frame now: 691.0
# Saved image  690 ----------frame now: 692.0
# Saved image  691 ----------frame now: 693.0
# Saved image  692 ----------frame now: 694.0
# Saved image  693 ----------frame now: 695.0
# Saved image  694 ----------frame now: 696.0
# Saved image  695 ----------frame now: 697.0
# Saved image  696 ----------frame now: 698.0
# Saved image  697 ----------frame now: 699.0
# Saved image  698 ----------frame now: 700.0
# Saved image  699 ----------frame now: 701.0
# Saved image  700 ----------frame now: 702.0
# Saved image  701 ----------frame now: 703.0
# Saved image  702 ----------frame now: 704.0
# Saved image  703 ----------frame now: 705.0
# Saved image  704 ----------frame now: 706.0
# Saved image  705 ----------frame now: 707.0
# Saved image  706 ----------frame now: 708.0
# Saved image  707 ----------frame now: 709.0
# Saved image  708 ----------frame now: 710.0
# Saved image  709 ----------frame now: 711.0
# Saved image  710 ----------frame now: 712.0
# Saved image  711 ----------frame now: 713.0
# Saved image  712 ----------frame now: 714.0
# Saved image  713 ----------frame now: 715.0
# Saved image  714 ----------frame now: 716.0
# Saved image  715 ----------frame now: 717.0
# Saved image  716 ----------frame now: 718.0
# Saved image  717 ----------frame now: 719.0
# Saved image  718 ----------frame now: 720.0
# Saved image  719 ----------frame now: 721.0
# Saved image  720 ----------frame now: 722.0
# Saved image  721 ----------frame now: 723.0
# Saved image  722 ----------frame now: 724.0
# Saved image  723 ----------frame now: 725.0
# Saved image  724 ----------frame now: 726.0
# Saved image  725 ----------frame now: 727.0
# Saved image  726 ----------frame now: 728.0
# Saved image  727 ----------frame now: 729.0
# Saved image  728 ----------frame now: 730.0
# Saved image  729 ----------frame now: 731.0
# Saved image  730 ----------frame now: 732.0
# Saved image  731 ----------frame now: 733.0
# Saved image  732 ----------frame now: 734.0
# Saved image  733 ----------frame now: 735.0
# Saved image  734 ----------frame now: 736.0
# Saved image  735 ----------frame now: 737.0
# Saved image  736 ----------frame now: 738.0
# Saved image  737 ----------frame now: 739.0
# Saved image  738 ----------frame now: 740.0
# Saved image  739 ----------frame now: 741.0
# Saved image  740 ----------frame now: 742.0
# Saved image  741 ----------frame now: 743.0
# Saved image  742 ----------frame now: 744.0
# Saved image  743 ----------frame now: 745.0
# Saved image  744 ----------frame now: 746.0
# Saved image  745 ----------frame now: 747.0
# Saved image  746 ----------frame now: 748.0
# Saved image  747 ----------frame now: 749.0
# Saved image  748 ----------frame now: 750.0
# Saved image  749 ----------frame now: 751.0
# Saved image  750 ----------frame now: 752.0
# Saved image  751 ----------frame now: 753.0
# Saved image  752 ----------frame now: 754.0
# Saved image  753 ----------frame now: 755.0
# Saved image  754 ----------frame now: 756.0
# Saved image  755 ----------frame now: 757.0
# Saved image  756 ----------frame now: 758.0
# Saved image  757 ----------frame now: 759.0
# Saved image  758 ----------frame now: 760.0
# Saved image  759 ----------frame now: 761.0
# Saved image  760 ----------frame now: 762.0
# Saved image  761 ----------frame now: 763.0
# Saved image  762 ----------frame now: 764.0
# Saved image  763 ----------frame now: 765.0
# Saved image  764 ----------frame now: 766.0
# Saved image  765 ----------frame now: 767.0
# Saved image  766 ----------frame now: 768.0
# Saved image  767 ----------frame now: 769.0
# Saved image  768 ----------frame now: 770.0
# Saved image  769 ----------frame now: 771.0
# Saved image  770 ----------frame now: 772.0
# Saved image  771 ----------frame now: 773.0
# Saved image  772 ----------frame now: 774.0
# Saved image  773 ----------frame now: 775.0
# Saved image  774 ----------frame now: 776.0
# Saved image  775 ----------frame now: 777.0
# Saved image  776 ----------frame now: 778.0
# Saved image  777 ----------frame now: 779.0
# Saved image  778 ----------frame now: 780.0
# Saved image  779 ----------frame now: 781.0
# Saved image  780 ----------frame now: 782.0
# Saved image  781 ----------frame now: 783.0
# Saved image  782 ----------frame now: 784.0
# Saved image  783 ----------frame now: 785.0
# Saved image  784 ----------frame now: 786.0
# Saved image  785 ----------frame now: 787.0
# Saved image  786 ----------frame now: 788.0
# Saved image  787 ----------frame now: 789.0
# Saved image  788 ----------frame now: 790.0
# Saved image  789 ----------frame now: 791.0
# Saved image  790 ----------frame now: 792.0
# Saved image  791 ----------frame now: 793.0
# Saved image  792 ----------frame now: 794.0
# Saved image  793 ----------frame now: 795.0
# Saved image  794 ----------frame now: 796.0
# Saved image  795 ----------frame now: 797.0
# Saved image  796 ----------frame now: 798.0
# Saved image  797 ----------frame now: 799.0
# Saved image  798 ----------frame now: 800.0
# Saved image  799 ----------frame now: 801.0
# Saved image  800 ----------frame now: 802.0
# Saved image  801 ----------frame now: 803.0
# Saved image  802 ----------frame now: 804.0
# Saved image  803 ----------frame now: 805.0
# Saved image  804 ----------frame now: 806.0
# Saved image  805 ----------frame now: 807.0
# Saved image  806 ----------frame now: 808.0
# Saved image  807 ----------frame now: 809.0
# Saved image  808 ----------frame now: 810.0
# Saved image  809 ----------frame now: 811.0
# Saved image  810 ----------frame now: 812.0
# Saved image  811 ----------frame now: 813.0
# Saved image  812 ----------frame now: 814.0
# Saved image  813 ----------frame now: 815.0
# Saved image  814 ----------frame now: 816.0
# Saved image  815 ----------frame now: 817.0
# Saved image  816 ----------frame now: 818.0
# Saved image  817 ----------frame now: 819.0
# Saved image  818 ----------frame now: 820.0
# Saved image  819 ----------frame now: 821.0
# Saved image  820 ----------frame now: 822.0
# Saved image  821 ----------frame now: 823.0
# Saved image  822 ----------frame now: 824.0
# Saved image  823 ----------frame now: 825.0
# Saved image  824 ----------frame now: 826.0
# Saved image  825 ----------frame now: 827.0
# Saved image  826 ----------frame now: 828.0
# Saved image  827 ----------frame now: 829.0
# Saved image  828 ----------frame now: 830.0
# Saved image  829 ----------frame now: 831.0
# Saved image  830 ----------frame now: 832.0
# Saved image  831 ----------frame now: 833.0
# Saved image  832 ----------frame now: 834.0
# Saved image  833 ----------frame now: 835.0
# Saved image  834 ----------frame now: 836.0
# Saved image  835 ----------frame now: 837.0
# Saved image  836 ----------frame now: 838.0
# Saved image  837 ----------frame now: 839.0
# Saved image  838 ----------frame now: 840.0
# Saved image  839 ----------frame now: 841.0
# Saved image  840 ----------frame now: 842.0
# Saved image  841 ----------frame now: 843.0
# Saved image  842 ----------frame now: 844.0
# Saved image  843 ----------frame now: 845.0
# Saved image  844 ----------frame now: 846.0
# Saved image  845 ----------frame now: 847.0
# Saved image  846 ----------frame now: 848.0
# Saved image  847 ----------frame now: 849.0
# Saved image  848 ----------frame now: 850.0
# Saved image  849 ----------frame now: 851.0
# Saved image  850 ----------frame now: 852.0
# Saved image  851 ----------frame now: 853.0
# Saved image  852 ----------frame now: 854.0
# Saved image  853 ----------frame now: 855.0
# Saved image  854 ----------frame now: 856.0
# Saved image  855 ----------frame now: 857.0
# Saved image  856 ----------frame now: 858.0
# Saved image  857 ----------frame now: 859.0
# Saved image  858 ----------frame now: 860.0
# Saved image  859 ----------frame now: 861.0
# Saved image  860 ----------frame now: 862.0
# Saved image  861 ----------frame now: 863.0
# Saved image  862 ----------frame now: 864.0
# Saved image  863 ----------frame now: 865.0
# Saved image  864 ----------frame now: 866.0
# Saved image  865 ----------frame now: 867.0
# Saved image  866 ----------frame now: 868.0
# Saved image  867 ----------frame now: 869.0
# Saved image  868 ----------frame now: 870.0
# Saved image  869 ----------frame now: 871.0
# Saved image  870 ----------frame now: 872.0
# Saved image  871 ----------frame now: 873.0
# Saved image  872 ----------frame now: 874.0
# Saved image  873 ----------frame now: 875.0
# Saved image  874 ----------frame now: 876.0
# Saved image  875 ----------frame now: 877.0
# Saved image  876 ----------frame now: 878.0
# Saved image  877 ----------frame now: 879.0
# Saved image  878 ----------frame now: 880.0
# Saved image  879 ----------frame now: 881.0
# Saved image  880 ----------frame now: 882.0
# Saved image  881 ----------frame now: 883.0
# Saved image  882 ----------frame now: 884.0
# Saved image  883 ----------frame now: 885.0
# Saved image  884 ----------frame now: 886.0
# Saved image  885 ----------frame now: 887.0
# Saved image  886 ----------frame now: 888.0
# Saved image  887 ----------frame now: 889.0
# Saved image  888 ----------frame now: 890.0
# Saved image  889 ----------frame now: 891.0
# Saved image  890 ----------frame now: 892.0
# Saved image  891 ----------frame now: 893.0
# Saved image  892 ----------frame now: 894.0
# Saved image  893 ----------frame now: 895.0
# Saved image  894 ----------frame now: 896.0
# Saved image  895 ----------frame now: 897.0
# Saved image  896 ----------frame now: 898.0
# Saved image  897 ----------frame now: 899.0
# Saved image  898 ----------frame now: 900.0
# Saved image  899 ----------frame now: 901.0
# Saved image  900 ----------frame now: 902.0
# Saved image  901 ----------frame now: 903.0
# Saved image  902 ----------frame now: 904.0
# Saved image  903 ----------frame now: 905.0
# Saved image  904 ----------frame now: 906.0
# Saved image  905 ----------frame now: 907.0
# Saved image  906 ----------frame now: 908.0
# Saved image  907 ----------frame now: 909.0
# Saved image  908 ----------frame now: 910.0
# Saved image  909 ----------frame now: 911.0
# Saved image  910 ----------frame now: 912.0
# Saved image  911 ----------frame now: 913.0
# Saved image  912 ----------frame now: 914.0
# Saved image  913 ----------frame now: 915.0
# Saved image  914 ----------frame now: 916.0
# Saved image  915 ----------frame now: 917.0
# Saved image  916 ----------frame now: 918.0
# Saved image  917 ----------frame now: 919.0
# Saved image  918 ----------frame now: 920.0
# Saved image  919 ----------frame now: 921.0
# Saved image  920 ----------frame now: 922.0
# Saved image  921 ----------frame now: 923.0
# Saved image  922 ----------frame now: 924.0
# Saved image  923 ----------frame now: 925.0
# Saved image  924 ----------frame now: 926.0
# Saved image  925 ----------frame now: 927.0
# Saved image  926 ----------frame now: 928.0
# Saved image  927 ----------frame now: 929.0
# Saved image  928 ----------frame now: 930.0
# Saved image  929 ----------frame now: 931.0
# Saved image  930 ----------frame now: 932.0
# Saved image  931 ----------frame now: 933.0
# Saved image  932 ----------frame now: 934.0
# Saved image  933 ----------frame now: 935.0
# Saved image  934 ----------frame now: 936.0
# Saved image  935 ----------frame now: 937.0
# Saved image  936 ----------frame now: 938.0
# Saved image  937 ----------frame now: 939.0
# Saved image  938 ----------frame now: 940.0
# Saved image  939 ----------frame now: 941.0
# Saved image  940 ----------frame now: 942.0
# Saved image  941 ----------frame now: 943.0
# Saved image  942 ----------frame now: 944.0
# Saved image  943 ----------frame now: 945.0
# Saved image  944 ----------frame now: 946.0
# Saved image  945 ----------frame now: 947.0
# Saved image  946 ----------frame now: 948.0
# Saved image  947 ----------frame now: 949.0
# Saved image  948 ----------frame now: 950.0
# Saved image  949 ----------frame now: 951.0
# Saved image  950 ----------frame now: 952.0
# Saved image  951 ----------frame now: 953.0
# Saved image  952 ----------frame now: 954.0
# Saved image  953 ----------frame now: 955.0
# Saved image  954 ----------frame now: 956.0
# Saved image  955 ----------frame now: 957.0
# Saved image  956 ----------frame now: 958.0
# Saved image  957 ----------frame now: 959.0
# Saved image  958 ----------frame now: 960.0
# Saved image  959 ----------frame now: 961.0
# Saved image  960 ----------frame now: 962.0
# Saved image  961 ----------frame now: 963.0
# Saved image  962 ----------frame now: 964.0
# Saved image  963 ----------frame now: 965.0
# Saved image  964 ----------frame now: 966.0
# Saved image  965 ----------frame now: 967.0
# Saved image  966 ----------frame now: 968.0
# Saved image  967 ----------frame now: 969.0
# Saved image  968 ----------frame now: 970.0
# Saved image  969 ----------frame now: 971.0
# Saved image  970 ----------frame now: 972.0
# Saved image  971 ----------frame now: 973.0
# Saved image  972 ----------frame now: 974.0
# Saved image  973 ----------frame now: 975.0
# Saved image  974 ----------frame now: 976.0
# Saved image  975 ----------frame now: 977.0
# Saved image  976 ----------frame now: 978.0
# Saved image  977 ----------frame now: 979.0
# Saved image  978 ----------frame now: 980.0
# Saved image  979 ----------frame now: 981.0
# Saved image  980 ----------frame now: 982.0
# Saved image  981 ----------frame now: 983.0
# Saved image  982 ----------frame now: 984.0
# Saved image  983 ----------frame now: 985.0
# Saved image  984 ----------frame now: 986.0
# Saved image  985 ----------frame now: 987.0
# Saved image  986 ----------frame now: 988.0
# Saved image  987 ----------frame now: 989.0
# Saved image  988 ----------frame now: 990.0
# Saved image  989 ----------frame now: 991.0
# Saved image  990 ----------frame now: 992.0
# Saved image  991 ----------frame now: 993.0
# Saved image  992 ----------frame now: 994.0
# Saved image  993 ----------frame now: 995.0
# Saved image  994 ----------frame now: 996.0
# Saved image  995 ----------frame now: 997.0
# Saved image  996 ----------frame now: 998.0
# Saved image  997 ----------frame now: 999.0
# Saved image  998 ----------frame now: 1000.0
# Saved image  999 ----------frame now: 1001.0
# Saved image  1000 ----------frame now: 1002.0
# Saved image  1001 ----------frame now: 1003.0
# Saved image  1002 ----------frame now: 1004.0
# Saved image  1003 ----------frame now: 1005.0
# Saved image  1004 ----------frame now: 1006.0
# Saved image  1005 ----------frame now: 1007.0
# Saved image  1006 ----------frame now: 1008.0
# Saved image  1007 ----------frame now: 1009.0
# Saved image  1008 ----------frame now: 1010.0
# Saved image  1009 ----------frame now: 1011.0
# Saved image  1010 ----------frame now: 1012.0
# Saved image  1011 ----------frame now: 1013.0
# Saved image  1012 ----------frame now: 1014.0
# Saved image  1013 ----------frame now: 1015.0
# Saved image  1014 ----------frame now: 1016.0
# Saved image  1015 ----------frame now: 1017.0
# Saved image  1016 ----------frame now: 1018.0
# Saved image  1017 ----------frame now: 1019.0
# Saved image  1018 ----------frame now: 1020.0
# Saved image  1019 ----------frame now: 1021.0
# Saved image  1020 ----------frame now: 1022.0
# Saved image  1021 ----------frame now: 1023.0
# Saved image  1022 ----------frame now: 1024.0
# Saved image  1023 ----------frame now: 1025.0
# Saved image  1024 ----------frame now: 1026.0
# Saved image  1025 ----------frame now: 1027.0
# Saved image  1026 ----------frame now: 1028.0
# Saved image  1027 ----------frame now: 1029.0
# Saved image  1028 ----------frame now: 1030.0
# Saved image  1029 ----------frame now: 1031.0
# Saved image  1030 ----------frame now: 1032.0
# Saved image  1031 ----------frame now: 1033.0
# Saved image  1032 ----------frame now: 1034.0
# Saved image  1033 ----------frame now: 1035.0
# Saved image  1034 ----------frame now: 1036.0
# Saved image  1035 ----------frame now: 1037.0
# Saved image  1036 ----------frame now: 1038.0
# Saved image  1037 ----------frame now: 1039.0
# Saved image  1038 ----------frame now: 1040.0
# Saved image  1039 ----------frame now: 1041.0
# Saved image  1040 ----------frame now: 1042.0
# Saved image  1041 ----------frame now: 1043.0
# Saved image  1042 ----------frame now: 1044.0
# Saved image  1043 ----------frame now: 1045.0
# Saved image  1044 ----------frame now: 1046.0
# Saved image  1045 ----------frame now: 1047.0
# Saved image  1046 ----------frame now: 1048.0
# Saved image  1047 ----------frame now: 1049.0
# Saved image  1048 ----------frame now: 1050.0
# Saved image  1049 ----------frame now: 1051.0
# Saved image  1050 ----------frame now: 1052.0
# Saved image  1051 ----------frame now: 1053.0
# Saved image  1052 ----------frame now: 1054.0
# Saved image  1053 ----------frame now: 1055.0
# Saved image  1054 ----------frame now: 1056.0
# Saved image  1055 ----------frame now: 1057.0
# Saved image  1056 ----------frame now: 1058.0
# Saved image  1057 ----------frame now: 1059.0
# Saved image  1058 ----------frame now: 1060.0
# Saved image  1059 ----------frame now: 1061.0
# Saved image  1060 ----------frame now: 1062.0
# Saved image  1061 ----------frame now: 1063.0
# Saved image  1062 ----------frame now: 1064.0
# Saved image  1063 ----------frame now: 1065.0
# Saved image  1064 ----------frame now: 1066.0
# Saved image  1065 ----------frame now: 1067.0
# Saved image  1066 ----------frame now: 1068.0
# Saved image  1067 ----------frame now: 1069.0
# Saved image  1068 ----------frame now: 1070.0
# Saved image  1069 ----------frame now: 1071.0
# Saved image  1070 ----------frame now: 1072.0
# Saved image  1071 ----------frame now: 1073.0
# Saved image  1072 ----------frame now: 1074.0
# Saved image  1073 ----------frame now: 1075.0
# Saved image  1074 ----------frame now: 1076.0
# Saved image  1075 ----------frame now: 1077.0
# Saved image  1076 ----------frame now: 1078.0
# Saved image  1077 ----------frame now: 1079.0
# Saved image  1078 ----------frame now: 1080.0
# Saved image  1079 ----------frame now: 1081.0
# Saved image  1080 ----------frame now: 1082.0
# Saved image  1081 ----------frame now: 1083.0
# Saved image  1082 ----------frame now: 1084.0
# Saved image  1083 ----------frame now: 1085.0
# Saved image  1084 ----------frame now: 1086.0
# Saved image  1085 ----------frame now: 1087.0
# Saved image  1086 ----------frame now: 1088.0
# Saved image  1087 ----------frame now: 1089.0
# Saved image  1088 ----------frame now: 1090.0
# Saved image  1089 ----------frame now: 1091.0
# Saved image  1090 ----------frame now: 1092.0
# ...
# Saved image  12950 ----------frame now: 12952.0
# Saved image  12951 ----------frame now: 12953.0
# Saved image  12952 ----------frame now: 12954.0
# Saved image  12953 ----------frame now: 12955.0
# Saved image  12954 ----------frame now: 12956.0
# Saved image  12955 ----------frame now: 12957.0
# Saved image  12956 ----------frame now: 12958.0
# Saved image  12957 ----------frame now: 12959.0
# Saved image  12958 ----------frame now: 12960.0
# Saved image  12959 ----------frame now: 12961.0
# Saved image  12960 ----------frame now: 12962.0
# Saved image  12961 ----------frame now: 12963.0
# Saved image  12962 ----------frame now: 12964.0
# Saved image  12963 ----------frame now: 12965.0
# Saved image  12964 ----------frame now: 12966.0
# Saved image  12965 ----------frame now: 12967.0
# Saved image  12966 ----------frame now: 12968.0
# Saved image  12967 ----------frame now: 12969.0
# Saved image  12968 ----------frame now: 12970.0
# Saved image  12969 ----------frame now: 12971.0
# Saved image  12970 ----------frame now: 12972.0
# Saved image  12971 ----------frame now: 12973.0
# Saved image  12972 ----------frame now: 12974.0
# Saved image  12973 ----------frame now: 12975.0
# Saved image  12974 ----------frame now: 12976.0
# Saved image  12975 ----------frame now: 12977.0
# Saved image  12976 ----------frame now: 12978.0
# Saved image  12977 ----------frame now: 12979.0
# Saved image  12978 ----------frame now: 12980.0
# Saved image  12979 ----------frame now: 12981.0
# Saved image  12980 ----------frame now: 12982.0
# Saved image  12981 ----------frame now: 12983.0
# Saved image  12982 ----------frame now: 12984.0
# Saved image  12983 ----------frame now: 12985.0
# Saved image  12984 ----------frame now: 12986.0
# Saved image  12985 ----------frame now: 12987.0
# Saved image  12986 ----------frame now: 12988.0
# Saved image  12987 ----------frame now: 12989.0
# Saved image  12988 ----------frame now: 12990.0
# Saved image  12989 ----------frame now: 12991.0
# Saved image  12990 ----------frame now: 12992.0
# Saved image  12991 ----------frame now: 12993.0
# Saved image  12992 ----------frame now: 12994.0
# Saved image  12993 ----------frame now: 12995.0
# Saved image  12994 ----------frame now: 12996.0
# Saved image  12995 ----------frame now: 12997.0
# Saved image  12996 ----------frame now: 12998.0
# Saved image  12997 ----------frame now: 12999.0
# Saved image  12998 ----------frame now: 13000.0
# Saved image  12999 ----------frame now: 13001.0
# Saved image  13000 ----------frame now: 13002.0
# Saved image  13001 ----------frame now: 13003.0
# Saved image  13002 ----------frame now: 13004.0
# Saved image  13003 ----------frame now: 13005.0
# Saved image  13004 ----------frame now: 13006.0
# Saved image  13005 ----------frame now: 13007.0
# Saved image  13006 ----------frame now: 13008.0
# Saved image  13007 ----------frame now: 13009.0
# Saved image  13008 ----------frame now: 13010.0
# Saved image  13009 ----------frame now: 13011.0
# Saved image  13010 ----------frame now: 13012.0
# Saved image  13011 ----------frame now: 13013.0
# Saved image  13012 ----------frame now: 13014.0
# Saved image  13013 ----------frame now: 13015.0
# Saved image  13014 ----------frame now: 13016.0
# Saved image  13015 ----------frame now: 13017.0
# Saved image  13016 ----------frame now: 13018.0
# Saved image  13017 ----------frame now: 13019.0
# Saved image  13018 ----------frame now: 13020.0
# Saved image  13019 ----------frame now: 13021.0
# Saved image  13020 ----------frame now: 13022.0
# Saved image  13021 ----------frame now: 13023.0
# Saved image  13022 ----------frame now: 13024.0
# Saved image  13023 ----------frame now: 13025.0
# Saved image  13024 ----------frame now: 13026.0
# Saved image  13025 ----------frame now: 13027.0
# Saved image  13026 ----------frame now: 13028.0
# Saved image  13027 ----------frame now: 13029.0
# Saved image  13028 ----------frame now: 13030.0
# Saved image  13029 ----------frame now: 13031.0
# Saved image  13030 ----------frame now: 13032.0
# Saved image  13031 ----------frame now: 13033.0
# Saved image  13032 ----------frame now: 13034.0
# Saved image  13033 ----------frame now: 13035.0
# Saved image  13034 ----------frame now: 13036.0
# Saved image  13035 ----------frame now: 13037.0
# Saved image  13036 ----------frame now: 13038.0
# Saved image  13037 ----------frame now: 13039.0
# Saved image  13038 ----------frame now: 13040.0
# Saved image  13039 ----------frame now: 13041.0
# Saved image  13040 ----------frame now: 13042.0
# Saved image  13041 ----------frame now: 13043.0
# Saved image  13042 ----------frame now: 13044.0
# Saved image  13043 ----------frame now: 13045.0
# Saved image  13044 ----------frame now: 13046.0
# Saved image  13045 ----------frame now: 13047.0
# Saved image  13046 ----------frame now: 13048.0
# Saved image  13047 ----------frame now: 13049.0
# Saved image  13048 ----------frame now: 13050.0
# Saved image  13049 ----------frame now: 13051.0
# Saved image  13050 ----------frame now: 13052.0
# Saved image  13051 ----------frame now: 13053.0
# Saved image  13052 ----------frame now: 13054.0
# Saved image  13053 ----------frame now: 13055.0
# Saved image  13054 ----------frame now: 13056.0
# Saved image  13055 ----------frame now: 13057.0
# Saved image  13056 ----------frame now: 13058.0
# Saved image  13057 ----------frame now: 13059.0
# Saved image  13058 ----------frame now: 13060.0
# Saved image  13059 ----------frame now: 13061.0
# Saved image  13060 ----------frame now: 13062.0
# Saved image  13061 ----------frame now: 13063.0
# Saved image  13062 ----------frame now: 13064.0
# Saved image  13063 ----------frame now: 13065.0
# Saved image  13064 ----------frame now: 13066.0
# Saved image  13065 ----------frame now: 13067.0
# Saved image  13066 ----------frame now: 13068.0
# Saved image  13067 ----------frame now: 13069.0
# Saved image  13068 ----------frame now: 13070.0
# Saved image  13069 ----------frame now: 13071.0
# Saved image  13070 ----------frame now: 13072.0
# Saved image  13071 ----------frame now: 13073.0
# Saved image  13072 ----------frame now: 13074.0
# Saved image  13073 ----------frame now: 13075.0
# Saved image  13074 ----------frame now: 13076.0
# Saved image  13075 ----------frame now: 13077.0
# Saved image  13076 ----------frame now: 13078.0
# Saved image  13077 ----------frame now: 13079.0
# Saved image  13078 ----------frame now: 13080.0
# Saved image  13079 ----------frame now: 13081.0
# Saved image  13080 ----------frame now: 13082.0
# Saved image  13081 ----------frame now: 13083.0
# Saved image  13082 ----------frame now: 13084.0
# Saved image  13083 ----------frame now: 13085.0
# Saved image  13084 ----------frame now: 13086.0
# Saved image  13085 ----------frame now: 13087.0
# Saved image  13086 ----------frame now: 13088.0
# Saved image  13087 ----------frame now: 13089.0
# Saved image  13088 ----------frame now: 13090.0
# Saved image  13089 ----------frame now: 13091.0
# Saved image  13090 ----------frame now: 13092.0
# Saved image  13091 ----------frame now: 13093.0
# Saved image  13092 ----------frame now: 13094.0
# Saved image  13093 ----------frame now: 13095.0
# Saved image  13094 ----------frame now: 13096.0
# Saved image  13095 ----------frame now: 13097.0
# Saved image  13096 ----------frame now: 13098.0
# Saved image  13097 ----------frame now: 13099.0
# Saved image  13098 ----------frame now: 13100.0
# Saved image  13099 ----------frame now: 13101.0
# Saved image  13100 ----------frame now: 13102.0
# Saved image  13101 ----------frame now: 13103.0
# Saved image  13102 ----------frame now: 13104.0
# Saved image  13103 ----------frame now: 13105.0
# Saved image  13104 ----------frame now: 13106.0
# Saved image  13105 ----------frame now: 13107.0
# Saved image  13106 ----------frame now: 13108.0
# Saved image  13107 ----------frame now: 13109.0
# Saved image  13108 ----------frame now: 13110.0
# Saved image  13109 ----------frame now: 13111.0
# Saved image  13110 ----------frame now: 13112.0
# Saved image  13111 ----------frame now: 13113.0
# Saved image  13112 ----------frame now: 13114.0
# Saved image  13113 ----------frame now: 13115.0
# Saved image  13114 ----------frame now: 13116.0
# Saved image  13115 ----------frame now: 13117.0
# Saved image  13116 ----------frame now: 13118.0
# Saved image  13117 ----------frame now: 13119.0
# Saved image  13118 ----------frame now: 13120.0
# Saved image  13119 ----------frame now: 13121.0
# Saved image  13120 ----------frame now: 13122.0
# Saved image  13121 ----------frame now: 13123.0
# Saved image  13122 ----------frame now: 13124.0
# Saved image  13123 ----------frame now: 13125.0
# Saved image  13124 ----------frame now: 13126.0
# Saved image  13125 ----------frame now: 13127.0
# Saved image  13126 ----------frame now: 13128.0
# Saved image  13127 ----------frame now: 13129.0
# Saved image  13128 ----------frame now: 13130.0
# Saved image  13129 ----------frame now: 13131.0
# Saved image  13130 ----------frame now: 13132.0
# Saved image  13131 ----------frame now: 13133.0
# Saved image  13132 ----------frame now: 13134.0
# Saved image  13133 ----------frame now: 13135.0
# Saved image  13134 ----------frame now: 13136.0
# Saved image  13135 ----------frame now: 13137.0
# Saved image  13136 ----------frame now: 13138.0
# Saved image  13137 ----------frame now: 13139.0
# Saved image  13138 ----------frame now: 13140.0
# Saved image  13139 ----------frame now: 13141.0
# Saved image  13140 ----------frame now: 13142.0
# Saved image  13141 ----------frame now: 13143.0
# Saved image  13142 ----------frame now: 13144.0
# Saved image  13143 ----------frame now: 13145.0
# Saved image  13144 ----------frame now: 13146.0
# Saved image  13145 ----------frame now: 13147.0
# Saved image  13146 ----------frame now: 13148.0
# Saved image  13147 ----------frame now: 13149.0
# Saved image  13148 ----------frame now: 13150.0
# Saved image  13149 ----------frame now: 13151.0
# Saved image  13150 ----------frame now: 13152.0
# Saved image  13151 ----------frame now: 13153.0
# Saved image  13152 ----------frame now: 13154.0
# Saved image  13153 ----------frame now: 13155.0
# Saved image  13154 ----------frame now: 13156.0
# Saved image  13155 ----------frame now: 13157.0
# Saved image  13156 ----------frame now: 13158.0
# Saved image  13157 ----------frame now: 13159.0
# Saved image  13158 ----------frame now: 13160.0
# Saved image  13159 ----------frame now: 13161.0
# Saved image  13160 ----------frame now: 13162.0
# Saved image  13161 ----------frame now: 13163.0
# Saved image  13162 ----------frame now: 13164.0
# Saved image  13163 ----------frame now: 13165.0
# Saved image  13164 ----------frame now: 13166.0
# Saved image  13165 ----------frame now: 13167.0
# Saved image  13166 ----------frame now: 13168.0
# Saved image  13167 ----------frame now: 13169.0
# Saved image  13168 ----------frame now: 13170.0
# Saved image  13169 ----------frame now: 13171.0
# Saved image  13170 ----------frame now: 13172.0
# Saved image  13171 ----------frame now: 13173.0
# Saved image  13172 ----------frame now: 13174.0
# Saved image  13173 ----------frame now: 13175.0
# Saved image  13174 ----------frame now: 13176.0
# Saved image  13175 ----------frame now: 13177.0
# Saved image  13176 ----------frame now: 13178.0
# Saved image  13177 ----------frame now: 13179.0
# Saved image  13178 ----------frame now: 13180.0
# Saved image  13179 ----------frame now: 13181.0
# Saved image  13180 ----------frame now: 13182.0
# Saved image  13181 ----------frame now: 13183.0
# Saved image  13182 ----------frame now: 13184.0
# Saved image  13183 ----------frame now: 13185.0
# Saved image  13184 ----------frame now: 13186.0
# Saved image  13185 ----------frame now: 13187.0
# Saved image  13186 ----------frame now: 13188.0
# Saved image  13187 ----------frame now: 13189.0
# Saved image  13188 ----------frame now: 13190.0
# Saved image  13189 ----------frame now: 13191.0
# Saved image  13190 ----------frame now: 13192.0
# Saved image  13191 ----------frame now: 13193.0
# Saved image  13192 ----------frame now: 13194.0
# Saved image  13193 ----------frame now: 13195.0
# Saved image  13194 ----------frame now: 13196.0
# Saved image  13195 ----------frame now: 13197.0
# Saved image  13196 ----------frame now: 13198.0
# Saved image  13197 ----------frame now: 13199.0
# Saved image  13198 ----------frame now: 13200.0
# Saved image  13199 ----------frame now: 13201.0
# Saved image  13200 ----------frame now: 13202.0
# Saved image  13201 ----------frame now: 13203.0
# Saved image  13202 ----------frame now: 13204.0
# Saved image  13203 ----------frame now: 13205.0
# Saved image  13204 ----------frame now: 13206.0
# Saved image  13205 ----------frame now: 13207.0
# Saved image  13206 ----------frame now: 13208.0
# Saved image  13207 ----------frame now: 13209.0
# Saved image  13208 ----------frame now: 13210.0
# Saved image  13209 ----------frame now: 13211.0
# Saved image  13210 ----------frame now: 13212.0
# Saved image  13211 ----------frame now: 13213.0
# Saved image  13212 ----------frame now: 13214.0
# Saved image  13213 ----------frame now: 13215.0
# Saved image  13214 ----------frame now: 13216.0
# Saved image  13215 ----------frame now: 13217.0
# Saved image  13216 ----------frame now: 13218.0
# Saved image  13217 ----------frame now: 13219.0
# Saved image  13218 ----------frame now: 13220.0
# Saved image  13219 ----------frame now: 13221.0
# Saved image  13220 ----------frame now: 13222.0
# Saved image  13221 ----------frame now: 13223.0
# Saved image  13222 ----------frame now: 13224.0
# Saved image  13223 ----------frame now: 13225.0
# Saved image  13224 ----------frame now: 13226.0
# Saved image  13225 ----------frame now: 13227.0
# Saved image  13226 ----------frame now: 13228.0
# Saved image  13227 ----------frame now: 13229.0
# Saved image  13228 ----------frame now: 13230.0
# Saved image  13229 ----------frame now: 13231.0
# Saved image  13230 ----------frame now: 13232.0
# Saved image  13231 ----------frame now: 13233.0
# Saved image  13232 ----------frame now: 13234.0
# Saved image  13233 ----------frame now: 13235.0
# Saved image  13234 ----------frame now: 13236.0
# Saved image  13235 ----------frame now: 13237.0
# Saved image  13236 ----------frame now: 13238.0
# Saved image  13237 ----------frame now: 13239.0
# Saved image  13238 ----------frame now: 13240.0
# Saved image  13239 ----------frame now: 13241.0
# Saved image  13240 ----------frame now: 13242.0
# Saved image  13241 ----------frame now: 13243.0
# Saved image  13242 ----------frame now: 13244.0
# Saved image  13243 ----------frame now: 13245.0
# Saved image  13244 ----------frame now: 13246.0
# Saved image  13245 ----------frame now: 13247.0
# Saved image  13246 ----------frame now: 13248.0
# Saved image  13247 ----------frame now: 13249.0
# Saved image  13248 ----------frame now: 13250.0
# Saved image  13249 ----------frame now: 13251.0
# Saved image  13250 ----------frame now: 13252.0
# Saved image  13251 ----------frame now: 13253.0
# Saved image  13252 ----------frame now: 13254.0
# Saved image  13253 ----------frame now: 13255.0
# Saved image  13254 ----------frame now: 13256.0
# Saved image  13255 ----------frame now: 13257.0
# Saved image  13256 ----------frame now: 13258.0
# Saved image  13257 ----------frame now: 13259.0
# Saved image  13258 ----------frame now: 13260.0
# Saved image  13259 ----------frame now: 13261.0
# Saved image  13260 ----------frame now: 13262.0
# Saved image  13261 ----------frame now: 13263.0
# Saved image  13262 ----------frame now: 13264.0
# Saved image  13263 ----------frame now: 13265.0
# Saved image  13264 ----------frame now: 13266.0
# Saved image  13265 ----------frame now: 13267.0
# Saved image  13266 ----------frame now: 13268.0
# Saved image  13267 ----------frame now: 13269.0
# Saved image  13268 ----------frame now: 13270.0
# Saved image  13269 ----------frame now: 13271.0
# Saved image  13270 ----------frame now: 13272.0
# Saved image  13271 ----------frame now: 13273.0
# Saved image  13272 ----------frame now: 13274.0
# Saved image  13273 ----------frame now: 13275.0
# Saved image  13274 ----------frame now: 13276.0
# Saved image  13275 ----------frame now: 13277.0
# Saved image  13276 ----------frame now: 13278.0
# Saved image  13277 ----------frame now: 13279.0
# Saved image  13278 ----------frame now: 13280.0
# Saved image  13279 ----------frame now: 13281.0
# Saved image  13280 ----------frame now: 13282.0
# Saved image  13281 ----------frame now: 13283.0
# Saved image  13282 ----------frame now: 13283.0

# %%
# vidcap = cv2.VideoCapture(pathmc + list0[7])
# success, image = vidcap.read()

# count = 0
# while success:
#   name = f'frame_{str(count).zfill(5)}.jpg'
#   cv2.imwrite(dir1 + name, image)    
#   success, image = vidcap.read()
#   print('Saved image ', count, '----------frame now:',vidcap.get(1))
#   count += 1
